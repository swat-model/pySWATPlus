# %%
# %load_ext autoreload

# %%
from pySWATPlus import TxtinoutReader
import logging

# %%
# Basic logging config
logging.basicConfig(
    level=logging.INFO,  # Show INFO and above
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# %%
# Path to the SWAT+ model folder
txtinout_folder = '/mnt/c/Users/joans/OneDrive/Escriptori/icra/muga_windows'
filename =  'plants.plt'
reader = TxtinoutReader(txtinout_folder)

# %%
params = {
    'plants.plt': {
        'has_units': False,
        'bm_e': [{
            'value': 150,
            'change_type': 'absval',
            'filter_by': "name == 'agrc'"
        }]
    },
}

run_config = reader.run_swat(params)
# Out:
# 2025-07-06 21:02:27,582 - INFO - SWAT+
# 2025-07-06 21:02:27,582 - INFO - Revision 60.5.7
# 2025-07-06 21:02:27,583 - INFO - Soil & Water Assessment Tool
# 2025-07-06 21:02:27,583 - INFO - PC Version
# 2025-07-06 21:02:27,584 - INFO - Program reading . . . executing
# 2025-07-06 21:02:27,621 - INFO - Date of Sim   7/ 6/2025 Time  21: 2:27
# 2025-07-06 21:02:27,622 - INFO - reading from precipitation file         Time  21: 2:27
# 2025-07-06 21:02:28,374 - INFO - reading from temperature file           Time  21: 2:27
# 2025-07-06 21:02:28,377 - INFO - reading from solar radiation file       Time  21: 2:28
# 2025-07-06 21:02:28,828 - INFO - reading from relative humidity file     Time  21: 2:28
# 2025-07-06 21:02:29,381 - INFO - reading from wind file                  Time  21: 2:28
# 2025-07-06 21:02:29,831 - INFO - reading from wgn file                   Time  21: 2:29
# 2025-07-06 21:02:29,907 - INFO - reading from wx station file            Time  21: 2:29
# ...

# %%
file = reader.register_file(
    filename=filename,
)

df = file.df
mask = df.query("name == 'agrl'").index 
df.loc[mask, 'bm_e'] = 100
file.overwrite_file()
df
# Out:
#         name     plnt_typ  gro_trig  nfix_co  days_mat   bm_e  harv_idx  \
# 0       agrc  cold_annual  temp_gro      0.0     110.0  150.0      0.40
# 1       agrl  warm_annual  temp_gro      0.0     110.0  100.0      0.45
# 2       agrr  warm_annual  temp_gro      0.0     110.0   39.0      0.50
# 3       alfa    perennial  temp_gro      0.5       0.0   28.0      0.90
# 4       almd    perennial  temp_gro      0.0       0.0   16.1      0.05
# ..       ...          ...       ...      ...       ...    ...       ...
# 256  wwht150  cold_annual  temp_gro      0.0     160.0   30.0      0.40
# 257  wwht160  cold_annual  temp_gro      0.0     160.0   30.0      0.40
# 258  wwht170  cold_annual  temp_gro      0.0     170.0   30.0      0.40
# 259     wetw    perennial  temp_gro      0.0       0.0   47.0      0.90
# 260     wetm    perennial  temp_gro      0.0       0.0   47.0      0.90
#
#      lai_pot  frac_hu1  lai_max1  ...  rt_st_end  plnt_pop1  frac_lai1  \
# ...

# %%
file.read_csv()
# Out:
# 'plants.plt: written by SWAT+ editor v2.2.0 on 2023-09-25 12:13 for SWAT+ rev.60.5.4\n'

# %%
reader.set_beginning_and_end_year(2009, 2025)

# %%
reader.set_warmup(6)

# %%
reader._copy_swat(target_dir='/home/zephol/test', overwrite=True)
# Out:
# '/home/zephol/test'

# %%
reader.enable_object_in_print_prt
